# %% [markdown]
# # 01 — EDA: SEC Filings
#
# Explore raw and extracted filings: section lengths, token counts, coverage by ticker/year/form type. **Phase 1 placeholder** — no data yet.

# %%
from pathlib import Path

from finsage.data.section_extractor import SectionExtractor

raw_dir = Path('../data/raw')
print('raw filings found:', len(list(raw_dir.glob('*.htm*'))))
extractor = SectionExtractor()
# TODO(phase-3): load a filing and inspect extracted sections.
