# %% [markdown]
# # 03 — Training Analysis
#
# Inspect QLoRA training curves (loss, eval loss, learning rate) from W&B / checkpoints. **Phase 1 placeholder** — populated after Phase 6.

# %%
from finsage.training.qlora_trainer import QLoRATrainer

lora, training = QLoRATrainer().load_configs()
print('lora config keys:', list(lora))
print('training config keys:', list(training))
# TODO(phase-6): plot training/eval loss from the W&B run.
