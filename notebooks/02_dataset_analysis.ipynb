# %% [markdown]
# # 02 — Instruction Dataset Analysis
#
# Inspect the JSONL dataset: task-type balance, input/output length distributions, and leakage checks across the company/year split. **Phase 1 placeholder.**

# %%
from finsage.data.instruction_builder import TASK_TYPES

print('task types:', len(TASK_TYPES))
for t in TASK_TYPES:
    print('-', t)
# TODO(phase-4): load data/datasets/*.jsonl and plot task-type counts.
