# %% [markdown]
# # 04 — Evaluation Results
#
# Compare base Mistral-7B vs FinSage-7B per task, build the benchmark table, and render figures for the report. **Phase 1 placeholder.**

# %%
from finsage.evaluation.report_generator import build_comparison_table

# Illustrative shape only — real numbers come from reports/*_results.json.
base = {'filing_qa_f1': 0.0, 'risk_summary_rouge_l': 0.0}
fine = {'filing_qa_f1': 0.0, 'risk_summary_rouge_l': 0.0}
print(build_comparison_table(base, fine))
# TODO(phase-7): load reports/base_results.json and reports/finetuned_results.json.
